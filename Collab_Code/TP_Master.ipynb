# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
os.chdir("/content/drive/MyDrive/TP_Master_PAR/Materials/code")

# %%
import sys

# Ajouter le répertoire
sys.path.append("/content/drive/MyDrive/TP_Master_PAR/Materials/code")

# %%
# Version 1
import ply
ply.read_ply("pointnet.py")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3d05eee10417> in <cell line: 2>()
#       1 import ply
# ----> 2 ply.read_ply("pointnet.py")
#
# /content/drive/MyDrive/TP_Master_PAR/Materials/code/ply.py in read_ply(filename)
#     120         # Check if the file start with ply
#     121         if b'ply' not in plyfile.readline():
# --> 122             raise ValueError('The file does not start whith the word ply')
#     123
#     124         # get binary_little/big or ascii
#
# ValueError: The file does not start whith the word ply

# %%
# Version 2
from ply import read_ply
read_ply("pointnet.py")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-32b558d3d295> in <cell line: 2>()
#       1 from ply import read_ply
# ----> 2 read_ply("pointnet.py")
#
# /content/drive/MyDrive/TP_Master_PAR/Materials/code/ply.py in read_ply(filename)
#     120         # Check if the file start with ply
#     121         if b'ply' not in plyfile.readline():
# --> 122             raise ValueError('The file does not start whith the word ply')
#     123
#     124         # get binary_little/big or ascii
#
# ValueError: The file does not start whith the word ply

# %%
import pointnet
